# %% [markdown]
# # **INDIVIDUAL WORK**
#
# ## Deadline: 23 February 2026 on Blackboard

# %% [markdown]
# ### **Object project**
#
# The student can choose the topic of the objects.
#
# Each student will be asked some questions in person about the project.
#
# **Please note: each unanswered or incorrectly answered question will result in points being deducted.**
#
# The student will have to deliver a proper object project.
#
# The complexity of the solution will be taken into account when evaluating the project.
#
# **It is not mandatory to cover all points**.
#
#   The more points covered (making sense), the better the final mark will be.
#
#   The better the quality of your design, the better your final mark will be.
#
# * Classes
# * Instances
# * Class attributes
# * Instance attributes
# * Mutable attributes
# * Immutable attributes
# * Hashable objects
# * Magic methods
# * Docstrings
# * Inheritance
# * Composition
# * *args
# * **kwargs
# * Default arguments
# * Positional arguments
# * keyword arguments
# * Decorators
# * Generators
# * Scripts
# * Paths
# * Collections
# * Iterables
# * Functions: Pass by reference vs pass by copy
# * Deep copy vs Shallow copy
# * Menus
# * Datetime
# * string format time
# * Regular expressions
# * argparse
# * APIs (path parameters, query parameters, body parameters)
# * .env
# * Readme.md
# * pyproject.toml
# * Object scope (global, local)
# * For loops
# * While loops
# * Recursion
#
# The student will submit the **commented code** in scripts, as well as a **pdf document** with the steps to develop the project (uv). The **pdf document** will specify which points have been covered with snippets from the code.
#
# Please, remember:
#
# Each student will be asked some questions in person about the project.
#
# **Note: each unanswered or incorrectly answered question will result in points being deducted.**
# ## Do your own work, you will have a brief project defense (a few minutes in person).
